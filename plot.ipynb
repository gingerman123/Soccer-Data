# %%
# 한글 폰트
import matplotlib as mpl 
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
import pandas as pd
import seaborn as sns

# %%
# 불러오기.
epl_df = pd.read_csv('Final_Data_update.csv',encoding='euc-kr') # 불러올 때도 encoding 꼭 넣기
epl_df
epl_df_rank = pd.read_csv('각 칼럼 상대 순위 데이터 update.csv',encoding='euc-kr')
# Out:
#       Team  Rank  Point  Score  Lose_score  Balance(m)  AverageAge     season  \
# 195    노팅엄    16     38     15           5           3          10  2022-2023
# 196    에버튼    17     36     19           8          18          13  2022-2023
# 197  레스터시티    18     34     11           4          19          12  2022-2023
# 198     리즈    19     31     12           1          16          18  2022-2023
# 199  사우스햄튼    20     25     18           2           7          20  2022-2023
#
#      goal_gain_lose_gap  Total_shots  Valid_shots  Goal_ratio(%)  \
# 195                  18           19           20             12
# 196                  15           17           17             17
# 197                  14           11           11              9
# 198                  17            9            9             13
# 199                  20           18           18             15
#
#      Valid_shot_ratio(%)  Shot_accuracy(%)
# 195                   20                11
# 196                   10                17
# 197                   11                10
# 198                   12                13
# 199                   16                15

# %% [markdown]
# # 우승과 가장 연관있는 데이터는?

# %%
epl_df_21 = epl_df
epl_df_12= epl_df_rank

# 순위와 득점
plt.figure(figsize=(12,6))
plt.subplot(211)
sns.scatterplot(x=epl_df_21['Rank'],y=epl_df_21['Score'])
sns.regplot(x=epl_df_21['Rank'],y=epl_df_21['Score'])


# 순위와 실점
plt.figure(figsize=(12,6))
plt.subplot(212)
sns.scatterplot(x=epl_df_21['Rank'],y=epl_df_21['Lose_score'])
sns.regplot(x=epl_df_21['Rank'],y=epl_df_21['Lose_score'])
plt.show()

# %%
# 순위와 득실차
plt.figure(figsize=(12,6))
sns.scatterplot(x=epl_df_21['Rank'],y=epl_df_21['goal_gain_lose_gap'])
sns.regplot(x=epl_df_21['Rank'],y=epl_df_21['goal_gain_lose_gap'])
plt.show()

# %%
# 순위와 총 지출액

plt.figure(figsize=(12,6))
sns.scatterplot(x=epl_df_12['Rank'],y=epl_df_12['Balance(m)'])
sns.regplot(x=epl_df_12['Rank'],y=epl_df_12['Balance(m)'])
plt.show()

# %%
# 순위와 평균 나이
plt.figure(figsize=(12,6))
sns.scatterplot(x=epl_df_21['Rank'],y=epl_df_21['AverageAge'])
sns.regplot(x=epl_df_21['Rank'],y=epl_df_21['AverageAge'])
plt.show()

# %% [markdown]
# # 15-16 시즌 레스터 시티 분석

# %%
epl_df_copy = epl_df.loc[epl_df.season == '2015-2016']
epl_df_copy = epl_df_copy.sort_values(by = 'Rank')
epl_df_copy
# Out:
#         Team  Rank  Point  Score  Lose_score  Balance(m)  AverageAge  \
# 46     레스터시티     1     81     68          36       40.45        27.3
# 41       아스날     2     71     65          36       24.00        26.6
# 56       토트넘     3     70     69          35      -16.25        24.2
# 48       맨시티     4     66     71          41      141.03        27.8
# 49        맨유     5     66     49          35       55.33        25.4
# 52     사우스햄튼     6     63     59          41        7.40        26.0
# 59      웨스트햄     7     62     65          51       34.19        26.4
# 47       리버풀     8     60     63          50       35.95        24.9
# 53     스토크시티     9     51     41          55       30.45        27.5
# 43        첼시    10     50     59          53        9.01        26.4
# 45       에버튼    11     47     59          55       37.20        26.5
# 55       스완지    12     47     42          52        5.01        27.5
# 57       왓포드    13     45     40          50       73.05        28.1
# 58  웨스트 브로미치    14     43     34          48       29.98        28.6
# 44  크리스탈 팰리스    15     42     39          51       23.40        27.5
# 40       본머스    16     42     45          67       54.46        27.5
# 54      선더랜드    17     39     48          62       55.05        27.2
# 50       뉴캐슬    18     37     44          65      102.48        25.2
# 51       노리치    19     34     39          67       29.01        27.7
# 42    아스톤 빌라    20     17     27          76        1.85        26.2
#
#        season  goal_gain_lose_gap  Total_shots  Valid_shots  Goal_ratio(%)  \
# 46  2015-2016                  32          365          183           18.6
# 41  2015-2016                  29          406          232           16.0
# 56  2015-2016                  34          456          260           15.1
# 48  2015-2016                  30          422          219           16.8
# 49  2015-2016                  14          299          161           16.4
# 52  2015-2016                  18          380          174           15.5
# 59  2015-2016                  14          390          193           16.7
# 47  2015-2016                  13          430          228           14.7
# 53  2015-2016                 -14          309          137           13.3
# 43  2015-2016                   6          374          192           15.8
# 45  2015-2016                   4          329          191           17.9
# 55  2015-2016                 -10          273          137           15.4
# 57  2015-2016                 -10          298          148           13.4
# 58  2015-2016                 -14          257          107           13.2
# 44  2015-2016                 -12          329          168           11.9
# 40  2015-2016                 -22          301          142           15.0
# 54  2015-2016                 -14          316          156           15.2
# 50  2015-2016                 -21          292          160           15.1
# 51  2015-2016                 -28          291          132           13.4
# 42  2015-2016                 -49          268          123           10.1
#
#     Valid_shot_ratio(%)  Shot_accuracy(%)
# 46            50.136986         37.158470
# 41            57.142857         28.017241
# 56            57.017544         26.538462
# 48            51.895735         32.420091
# 49            53.846154         30.434783
# 52            45.789474         33.908046
# 59            49.487179         33.678756
# 47            53.023256         27.631579
# 53            44.336570         29.927007
# 43            51.336898         30.729167
# 45            58.054711         30.890052
# 55            50.183150         30.656934
# 57            49.664430         27.027027
# 58            41.634241         31.775701
# 44            51.063830         23.214286
# 40            47.176080         31.690141
# 54            49.367089         30.769231
# 50            54.794521         27.500000
# 51            45.360825         29.545455
# 42            45.895522         21.951220

# %% [markdown]
# ## 시즌 내 레스터 시티

# %%
# 레스터시티 순위

plt.figure(figsize=(12,6))
sns.barplot(x = epl_df_copy['Team'],y =epl_df_copy['Rank'])
plt.xticks(rotation = 45)
plt.ylim([22,0])
plt.gca().invert_yaxis() #축 변환해야 아래부터 그래프 나옴
# 그래프 위에 value 표시하기
for i, value in enumerate(epl_df_copy['Rank']):
    plt.text(i, value + 0.1, value, ha='center', va='bottom')
plt.xlabel('팀',loc='center')
plt.ylabel('팀 순위',loc='center')
plt.title('2015-2016시즌 팀 별 순위',loc='center')
plt.show()

# %%
# 2015-2016시즌 팀 별 득점
plt.figure(figsize=(12,6))
sns.barplot(x = epl_df_copy['Team'],y =epl_df_copy['Score'])
for i, value in enumerate(epl_df_copy['Score']):
    plt.text(i, value + 0.1, value, ha='center', va='bottom')
plt.xticks(rotation=45)
plt.xlabel('팀',loc='center')
plt.ylabel('득점',loc='center')
plt.title('2015-2016시즌 팀 별 득점',loc='center')
plt.show()

# %%
# 2015-2016 팀 별 실점
plt.figure(figsize=(12,6))
sns.barplot(x= epl_df_copy['Team'],y =epl_df_copy['Lose_score'])
for i, value in enumerate(epl_df_copy['Lose_score']):
    plt.text(i, value + 0.1, value, ha='center', va='bottom')
plt.xticks(rotation=45)
plt.xlabel('팀',loc='center')
plt.ylabel('실점',loc='center')
plt.title('2015-2016시즌 팀 별 실점',loc='center')
plt.show()

# %%
# 2015-2016 팀 별 총 슈팅 개수
plt.figure(figsize=(12,6))
sns.barplot(x= epl_df_copy['Team'],y =epl_df_copy['Total_shots'])
plt.xticks(rotation=45)
for i, value in enumerate(epl_df_copy['Total_shots']):
    plt.text(i, value + 0.1, value, ha='center', va='bottom')
plt.xlabel('팀',loc='center')
plt.ylabel('슈팅개수',loc='center')
plt.title('2015-2016시즌 팀 별 총 슈팅개수',loc='center')
plt.show()

# %%
# 2015-2016 팀 별 총 슈팅 개수
plt.figure(figsize=(12,6))
sns.barplot(x= epl_df_copy['Team'],y =epl_df_copy['Goal_ratio(%)'])
plt.xticks(rotation=45)
for i, value in enumerate(epl_df_copy['Goal_ratio(%)']):
    plt.text(i, value + 0.1, value, ha='center', va='bottom')
plt.xlabel('팀',loc='center')
plt.ylabel('슈팅 당 골 비율(%)',loc='center')
plt.title('2015-2016시즌 팀 별 슈팅 당 골 비율',loc='center')
plt.show()

# %% [markdown]
# ## 10시즌 내 레스터 시티

# %%
# 10시즌간 1위팀들의 역대 득점

epl_df_lei = epl_df.loc[epl_df.Rank == 1]
epl_df_lei
plt.figure(figsize=(12,6))
sns.barplot(x = epl_df_lei['season'],y =epl_df_lei['Score'])
plt.xticks(rotation=45)
for i, value in enumerate(epl_df_lei['Score']):
    plt.text(i, value + 0.1, value, ha='center', va='bottom')
plt.xlabel('시즌',loc='center')
plt.ylabel('득점',loc='center')
plt.title('10시즌간 1위팀의 득점',loc='center')
plt.show()

# %%
# 10시즌간 1위 팀의 실점
plt.figure(figsize=(12,6))
sns.barplot(x = epl_df_lei['season'],y =epl_df_lei['Lose_score'])
plt.xticks(rotation=45)
for i, value in enumerate(epl_df_lei['Lose_score']):
    plt.text(i, value + 0.1, value, ha='center', va='bottom')
plt.xlabel('시즌',loc='center')
plt.ylabel('실점',loc='center')
plt.title('10시즌간 1위팀의 실점',loc='center')
plt.show()

# %%
# 10시즌간 1위 팀의 슈팅 개수
plt.figure(figsize=(12,6))
sns.barplot(x = epl_df_lei['season'],y =epl_df_lei['Total_shots'])
plt.xticks(rotation=45)
for i, value in enumerate(epl_df_lei['Total_shots']):
    plt.text(i, value + 0.1, value, ha='center', va='bottom')
plt.xlabel('시즌',loc='center')
plt.ylabel('슈팅 개수',loc='center')
plt.title('10시즌간 1위팀의 슈팅 개수',loc='center')
plt.show()

# %%
# 10시즌간 1위 팀의 슈팅 당 골 비율
plt.figure(figsize=(12,6))
sns.barplot(x = epl_df_lei['season'],y =epl_df_lei['Goal_ratio(%)'])
plt.xticks(rotation=45)
for i, value in enumerate(epl_df_lei['Goal_ratio(%)']):
    plt.text(i, value + 0.1, value, ha='center', va='bottom')
plt.xlabel('시즌',loc='center')
plt.ylabel('슈팅 당 골 비율(%)',loc='center')
plt.title('10시즌간 1위팀의 슈팅 당 골 비율',loc='center')
plt.show()
